# %%
from internal.Agent.AgentFlow import create_agent
from langchain_core.messages import HumanMessage

agent = create_agent()

# %%
from IPython.display import Image, display
display(Image(agent.get_graph().draw_mermaid_png()))

# %%
from internal.Agent.memory import AgentState

state = AgentState(messages=[HumanMessage(content='Merhaba benim adım enes.')])

result = agent.invoke(state)

print("\nAgent Response:")
print(result)
# Out:
# [SystemMessage(content='You are a very helpful assistant for read some documents.Then you get inference on them.But just about this documents.You are get the inference and if you need some research on internet.Then you ouse some Tools.', additional_kwargs={}, response_metadata={})]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       1 from internal.Agent.memory import AgentState
#       3 state = AgentState(messages=[HumanMessage(content='Merhaba benim adım enes.')])
# ----> 5 result = agent.invoke(state)
#       7 print("\nAgent Response:")
#       8 print(result)
#
# File ~/Documents/RealTimeUrgencyAgent/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2719, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2716 chunks: list[Union[dict[str, Any], Any]] = []
#    2717 interrupts: list[Interrupt] = []
# -> 2719 for chunk in self.stream(
#    2720     input,
#    2721     config,
#    2722     stream_mode=stream_mode,
#    2723     output_keys=output_keys,
#    2724     interrupt_before=interrupt_before,
#    2725     interrupt_after=interrupt_after,
#    2726     checkpoint_during=checkpoint_during,
#    2727     debug=debug,
#    2728     **kwargs,
#    2729 ):
#    2730     if stream_mode == "values":
#    2731         if (
#    2732             isinstance(chunk, dict)
#    2733             and (ints := chunk.get(INTERRUPT)) is not None
#    2734         ):
#
# File ~/Documents/RealTimeUrgencyAgent/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File ~/Documents/RealTimeUrgencyAgent/internal/Agent/Node/LLMNode.py:15, in llm_node(state)
#      13 tools = [document_loader, retriever_in_db]
#      14 llm = ChatOpenAI(temperature=0.0, model='gpt-4o-mini', api_key=os.getenv('OPENAI_API_KEY')).bind_tools(tools=tools)
# ---> 15 print(state['messages'])
#      16 response = llm.invoke(state['messages'])
#      17 state['messages'].append(response)
#
# KeyError: 'messages'
# During task with name 'llm_node' and id 'bd8f9a37-d6cd-dd89-9ac6-08af0e25e819'
